# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarfaraz021/Loading-data-to-hugging-face-hub/blob/main/Loadinddatasettohub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install datasets huggingface_hub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login

# Replace 'your_hf_token' with your actual Hugging Face token
login(token="your token")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from huggingface_hub import login
from datasets import Dataset

# Replace 'your_write_token' with your actual Hugging Face token with write permissions
login(token="your token", add_to_git_credential=True)

# Load your CSV file into a dataset
dataset = Dataset.from_csv("/content/employees_schedule_2023_2024.csv")

# Define your repository name in the correct format
repo_name = "ahmed01111/employees_schedule_2023_24"

# Upload the dataset to Hugging Face Hub
dataset.push_to_hub(repo_name)
# Out:
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# ...
# Creating parquet from Arrow format:   0%|          | 0/21 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/ahmed01111/employees_schedule_2023_24/commit/04744dd4696b5e37380e3d594bc0e169563989ba', commit_message='Upload dataset', commit_description='', oid='04744dd4696b5e37380e3d594bc0e169563989ba', pr_url=None, pr_revision=None, pr_num=None)
